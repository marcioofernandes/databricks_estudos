-- %% [markdown]
-- Copiando pastas e arquivos para seu Workspace

-- %%
%python
#copia de arquivos de um dbfs para um workspace
dbutils.fs.cp("dbfs:/mnt/iot/iot_devices.json",
               "file:/Workspace/Users/edmilson.onanalytics@gmail.com/Databricks-Curso/00.Arquivos-Datasets/iot/iot_devices.json"
               )

-- %%
%python
display (dbutils.fs.ls("dbfs:/databricks-datasets/bikeSharing/data-001"))

-- %%
%python
# Copia recursivamente todos os arquivos e subdiretórios de um diretório DBFS para um diretório no workspace
dbutils.fs.cp(
    "dbfs:/databricks-datasets/bikeSharing/data-001", 
    "file:/Workspace/Users/edmilson.onanalytics@gmail.com/Databricks-Curso/00.Arquivos-Datasets/bikeSharing/data-001", 
    recurse=True
)
